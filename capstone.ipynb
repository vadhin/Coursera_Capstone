# %% [markdown]
# ## Capstone projekt for coursera

# %%
### Load the Pandas libraries with alias 'pd' 
import pandas as pd

# %%
### Load the Numpy libraries with alias 'np' 
import numpy as np

# %%
print ("Hello Capstone Project Course!")
